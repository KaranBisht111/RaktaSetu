# %%
# ==============================================================
# 🩸 Blood Demand Forecasting - Deep Learning (LSTM)
# BE Final Year Project
# PART 1 - Environment Setup & Data Validation
# ==============================================================

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from sklearn.preprocessing import MinMaxScaler
import warnings
warnings.filterwarnings("ignore")
# Out:
# C:\Users\bisht\AppData\Roaming\Python\Python313\site-packages\keras\src\export\tf2onnx_lib.py:8: FutureWarning: In the future `np.object` will be defined as the corresponding NumPy scalar.
#   if not hasattr(np, "object"):

# %%
# --------------------------------------------------------------
# 🎨 Professional Visualization Settings
# --------------------------------------------------------------
# %matplotlib inline
sns.set_style("whitegrid")
plt.rcParams['figure.figsize'] = (14, 6)
plt.rcParams['axes.titlesize'] = 14
plt.rcParams['axes.labelsize'] = 12

print("✅ Deep Learning Environment Initialized")
print("TensorFlow Version:", tf.__version__)
# Out:
# ✅ Deep Learning Environment Initialized
# TensorFlow Version: 2.20.0

# %%
# ==============================================================
# 📂 1. Load Dataset
# ==============================================================

print("\n📂 Loading Dataset...")
demand = pd.read_csv("synthetic_blood_demand_250k.csv")

print("Initial Shape:", demand.shape)
print("Columns:", demand.columns.tolist())

# Convert Date Column Safely
demand['Date'] = pd.to_datetime(demand['Date'], dayfirst=True, errors='coerce')
# Out:
# 📂 Loading Dataset...
# Initial Shape: (250000, 10)
# Columns: ['Date', 'Hospital_ID', 'Hospital_Name', 'Hospital_Location', 'Location_Pincode', 'Blood_Type', 'Units_Demanded', 'Day_of_Week', 'is_monsoon_peak', 'is_major_festival']

# %%
# ==============================================================
# 🧪 DATA VALIDATION TEST
# ==============================================================

broken_dates = demand['Date'].isna().sum()

if broken_dates > 0:
    print(f"⚠️ Found {broken_dates} invalid date entries. Removing...")
    demand = demand.dropna(subset=['Date'])

print("After Cleaning Shape:", demand.shape)

# Check for missing values
print("\n🔍 Missing Values Check:")
print(demand.isnull().sum())

# Basic Statistical Summary
print("\n📊 Statistical Summary:")
print(demand.describe())

print("\n✅ PART 1 Completed Successfully")
# Out:
# After Cleaning Shape: (250000, 10)
#
# 🔍 Missing Values Check:
# Date                 0
# Hospital_ID          0
# Hospital_Name        0
# Hospital_Location    0
# Location_Pincode     0
# Blood_Type           0
# Units_Demanded       0
# Day_of_Week          0
# is_monsoon_peak      0
# is_major_festival    0
# dtype: int64
#
# 📊 Statistical Summary:
#                                 Date  Location_Pincode  Units_Demanded  \
# count                         250000     250000.000000   250000.000000
# mean   2022-12-31 10:01:56.582400256     400031.526516       46.630836
# min              2020-01-01 00:00:00     400004.000000        5.000000
# 25%              2021-07-01 00:00:00     400012.000000       21.000000
# 50%              2022-12-31 00:00:00     400022.000000       38.000000
# 75%              2024-07-01 00:00:00     400053.000000       70.000000
# max              2025-12-31 00:00:00     400080.000000      155.000000
# std                              NaN         24.095450       29.912287
#
#        is_monsoon_peak  is_major_festival
# count    250000.000000      250000.000000
# mean          0.333952           0.002732
# min           0.000000           0.000000
# 25%           0.000000           0.000000
# 50%           0.000000           0.000000
# 75%           1.000000           0.000000
# max           1.000000           1.000000
# std           0.471624           0.052197
#
# ✅ PART 1 Completed Successfully

# %%
# ==============================================================
# 📊 PART 2 - Daily Aggregation & Professional Visualization
# ==============================================================

print("\n📊 Creating Daily Aggregated Demand...")

# Aggregate Total Units Per Day
daily_demand = demand.groupby('Date')['Units_Demanded'].sum().reset_index()
daily_demand.set_index('Date', inplace=True)

print("Total Clean Days:", len(daily_demand))
print("Date Range:", daily_demand.index.min(), "to", daily_demand.index.max())
# Out:
# 📊 Creating Daily Aggregated Demand...
# Total Clean Days: 2192
# Date Range: 2020-01-01 00:00:00 to 2025-12-31 00:00:00

# %%
# ==============================================================
# 🧪 VALIDATION TEST 1 - Check Time Continuity
# ==============================================================

date_diff = daily_demand.index.to_series().diff().dropna().value_counts()

print("\n🔍 Date Interval Distribution:")
print(date_diff.head())

if len(date_diff) == 1:
    print("✅ Time Series is Continuous (Daily)")
else:
    print("⚠️ Irregular Date Gaps Detected (Check Data)")

print("\n✅ PART 2 Completed Successfully")
# Out:
# 🔍 Date Interval Distribution:
# Date
# 1 days    2191
# Name: count, dtype: int64
# ✅ Time Series is Continuous (Daily)
#
# ✅ PART 2 Completed Successfully

# %%
# ==============================================================
# 📈 Visualization 1 - Full Demand Trend
# ==============================================================

plt.figure()
plt.plot(daily_demand.index,
         daily_demand['Units_Demanded'],
         color='darkred',
         linewidth=1.5)

plt.title("Mumbai Hospital Daily Blood Demand Trend")
plt.xlabel("Date")
plt.ylabel("Units Consumed")
plt.tight_layout()
plt.show()

# %%
# ==============================================================
# 📊 Visualization 2 - Monthly Seasonality Pattern
# ==============================================================

monthly_avg = daily_demand.resample('M').mean()

plt.figure()
plt.plot(monthly_avg.index,
         monthly_avg['Units_Demanded'],
         marker='o')

plt.title("Monthly Average Blood Demand (Seasonality Insight)")
plt.xlabel("Month")
plt.ylabel("Average Units")
plt.tight_layout()
plt.show()

# %%
# ==============================================================
# 🧪 VALIDATION TEST 2 - Demand Stability Check
# ==============================================================

print("\n📊 Demand Statistics:")
print("Mean Daily Demand:", round(daily_demand['Units_Demanded'].mean(), 2))
print("Std Dev:", round(daily_demand['Units_Demanded'].std(), 2))
print("Max Demand:", daily_demand['Units_Demanded'].max())
print("Min Demand:", daily_demand['Units_Demanded'].min())
# Out:
# 📊 Demand Statistics:
# Mean Daily Demand: 5318.3
# Std Dev: 509.54
# Max Demand: 6425
# Min Demand: 4310

# %%
# ==============================================================
# 🔄 PART 3 - Data Normalization (Production Safe)
# ==============================================================

print("\n🔄 Normalizing Data for LSTM Model...")

# Create scaler (THIS is your demand_scaler)
demand_scaler = MinMaxScaler(feature_range=(0, 1))

# Fit and transform
scaled_data = demand_scaler.fit_transform(daily_demand)

print("Scaled Data Shape:", scaled_data.shape)
# Out:
# 🔄 Normalizing Data for LSTM Model...
# Scaled Data Shape: (2192, 1)

# %%
# ==============================================================
# 🧪 VALIDATION TEST 1 - Check Scaling Range
# ==============================================================

print("\n🔍 Scaling Validation:")
print("Minimum value after scaling:", scaled_data.min())
print("Maximum value after scaling:", scaled_data.max())

if scaled_data.min() >= 0 and scaled_data.max() <= 1:
    print("✅ Scaling Successful (Values between 0 and 1)")
else:
    print("⚠️ Scaling Issue Detected")
# Out:
# 🔍 Scaling Validation:
# Minimum value after scaling: 0.0
# Maximum value after scaling: 1.0
# ✅ Scaling Successful (Values between 0 and 1)

# %%
# ==============================================================
# 💾 Save demand_scaler for Backend Use
# ==============================================================

import os
import joblib

os.makedirs("ml_models", exist_ok=True)

joblib.dump(demand_scaler, "ml_models/demand_scaler.pkl")

print("✅ demand_scaler.pkl saved successfully inside ml_models/")
# Out:
# ✅ demand_scaler.pkl saved successfully inside ml_models/

# %%
# ==============================================================
# 🧪 VALIDATION TEST 2 - Reload Test (Very Important)
# ==============================================================

loaded_scaler = joblib.load("ml_models/demand_scaler.pkl")

test_inverse = loaded_scaler.inverse_transform(
    scaled_data[:5]
)

print("\n🔍 Reload Test (First 5 values after inverse transform):")
print(test_inverse.flatten())

print("\n✅ PART 3 Completed Successfully")
# Out:
# 🔍 Reload Test (First 5 values after inverse transform):
# [5042. 4868. 5025. 4652. 4681.]
#
# ✅ PART 3 Completed Successfully

# %%
# ==============================================================
# 🔁 PART 4 - Sequence Creation (Sliding Window for LSTM)
# ==============================================================

print("\n🔁 Creating Time-Series Sequences...")

# Original Logic (unchanged)
def create_sequences(data, window_size=14):
    X, y = [], []
    for i in range(window_size, len(data)):
        X.append(data[i-window_size:i, 0])
        y.append(data[i, 0])
    return np.array(X), np.array(y)

window_size = 14

X_dl, y_dl = create_sequences(scaled_data, window_size)

print("Total Sequences Created:", len(X_dl))
print("Input Shape Before Reshape:", X_dl.shape)
# Out:
# 🔁 Creating Time-Series Sequences...
# Total Sequences Created: 2178
# Input Shape Before Reshape: (2178, 14)

# %%
# ==============================================================
# 🧪 VALIDATION TEST 1 - Check Window Logic
# ==============================================================

print("\n🔍 Window Validation Example:")

print("First Window (Scaled Values):")
print(X_dl[0])

print("\nTarget for First Window:")
print(y_dl[0])

if len(X_dl[0]) == window_size:
    print("\n✅ Window Size Correct")
else:
    print("\n⚠️ Window Size Mismatch")
# Out:
# 🔍 Window Validation Example:
# First Window (Scaled Values):
# [0.34609929 0.26382979 0.33806147 0.16170213 0.17541371 0.43026005
#  0.41323877 0.31111111 0.3286052  0.31111111 0.22978723 0.31252955
#  0.27565012 0.34326241]
#
# Target for First Window:
# 0.3735224586288415
#
# ✅ Window Size Correct

# %%
# ==============================================================
# 🔄 Reshape for LSTM [Samples, Time Steps, Features]
# ==============================================================

X_dl = X_dl.reshape((X_dl.shape[0], X_dl.shape[1], 1))

print("\nReshaped Input Shape for LSTM:", X_dl.shape)
# Out:
# Reshaped Input Shape for LSTM: (2178, 14, 1)

# %%
# ==============================================================
# 🧪 VALIDATION TEST 2 - Shape Check
# ==============================================================

if len(X_dl.shape) == 3:
    print("✅ LSTM Input Format Correct (3D)")
else:
    print("⚠️ LSTM Input Format Incorrect")

print("\n✅ PART 4 Completed Successfully")
# Out:
# ✅ LSTM Input Format Correct (3D)
#
# ✅ PART 4 Completed Successfully

# %%
# ==============================================================
# 📂 PART 5 - Train/Test Split
# ==============================================================

print("\n📂 Splitting Data into Training and Testing Sets...")

# Original Logic (unchanged)
split = int(len(X_dl) * 0.8)

X_train, X_test = X_dl[:split], X_dl[split:]
y_train, y_test = y_dl[:split], y_dl[split:]

print("Training Samples:", len(X_train))
print("Testing Samples:", len(X_test))
# Out:
# 📂 Splitting Data into Training and Testing Sets...
# Training Samples: 1742
# Testing Samples: 436

# %%
# ==============================================================
# 🧪 VALIDATION TEST 1 - Shape Check
# ==============================================================

print("\n🔍 Shape Verification:")
print("X_train shape:", X_train.shape)
print("y_train shape:", y_train.shape)
print("X_test shape:", X_test.shape)
print("y_test shape:", y_test.shape)

if len(X_train) > 0 and len(X_test) > 0:
    print("✅ Train/Test Split Successful")
else:
    print("⚠️ Split Error Detected")
# Out:
# 🔍 Shape Verification:
# X_train shape: (1742, 14, 1)
# y_train shape: (1742,)
# X_test shape: (436, 14, 1)
# y_test shape: (436,)
# ✅ Train/Test Split Successful

# %%
# ==============================================================
# 📊 Distribution Check (Scaled Target Values)
# ==============================================================

plt.figure()
plt.hist(y_train, bins=30)
plt.title("Distribution of Training Target Values (Scaled)")
plt.xlabel("Scaled Demand")
plt.ylabel("Frequency")
plt.tight_layout()
plt.show()

# %%
# ==============================================================
# 🧪 VALIDATION TEST 2 - Data Leakage Check
# ==============================================================

if X_train.shape[0] + X_test.shape[0] == X_dl.shape[0]:
    print("✅ No Data Leakage in Split")
else:
    print("⚠️ Potential Split Mismatch")

print("\n✅ PART 5 Completed Successfully")
# Out:
# ✅ No Data Leakage in Split
#
# ✅ PART 5 Completed Successfully

# %%
# ==============================================================
# 🧠 PART 6 - LSTM Model Architecture
# ==============================================================

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout

print("\n🧠 Building LSTM Model Architecture...")

# Original Architecture (UNCHANGED)
model = Sequential([
    LSTM(40, return_sequences=True, input_shape=(window_size, 1)),
    Dropout(0.25),
    LSTM(40, return_sequences=False),
    Dropout(0.25),
    Dense(20, activation='relu'),
    Dense(1)
])

# Original Optimizer (UNCHANGED)
optimizer = tf.keras.optimizers.Adam(learning_rate=0.001)

model.compile(
    optimizer=optimizer,
    loss='mean_squared_error'
)

print("✅ Model Compiled Successfully")
# Out:
# 🧠 Building LSTM Model Architecture...
# ✅ Model Compiled Successfully

# %%
# ==============================================================
# 🧪 VALIDATION TEST 1 - Model Summary
# ==============================================================

print("\n📊 Model Summary:")
model.summary()
# Out:
# 📊 Model Summary:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                          │ (None, 14, 40)              │           6,720 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 14, 40)              │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_1 (LSTM)                        │ (None, 40)                  │          12,960 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 40)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 20)                  │             820 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 1)                   │              21 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 20,521 (80.16 KB)
#  Trainable params: 20,521 (80.16 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# ==============================================================
# 🧪 VALIDATION TEST 2 - Parameter Count Check
# ==============================================================

total_params = model.count_params()
print("\nTotal Trainable Parameters:", total_params)

if total_params > 0:
    print("✅ Model Parameters Verified")
else:
    print("⚠️ Model Parameter Issue")

print("\n✅ PART 6 Completed Successfully")
# Out:
# Total Trainable Parameters: 20521
# ✅ Model Parameters Verified
#
# ✅ PART 6 Completed Successfully

# %%
# ==============================================================
# 🧠 PART 7 - Model Training
# ==============================================================

early_stop = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',
    patience=5,
    restore_best_weights=True
)

history = model.fit(
    X_train,
    y_train,
    batch_size=16,
    epochs=50,
    validation_data=(X_test, y_test),
    callbacks=[early_stop],
    verbose=1
)
# Out:
# Epoch 1/50
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 16s 44ms/step - loss: 0.0347 - val_loss: 0.0159
# Epoch 2/50
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - loss: 0.0193 - val_loss: 0.0140
# Epoch 3/50
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 5s 27ms/step - loss: 0.0175 - val_loss: 0.0162
# Epoch 4/50
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 0.0172 - val_loss: 0.0144
# Epoch 5/50
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 0.0167 - val_loss: 0.0142
# Epoch 6/50
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 0.0162 - val_loss: 0.0134
# Epoch 7/50
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 0.0158 - val_loss: 0.0143
# Epoch 8/50
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 5s 27ms/step - loss: 0.0156 - val_loss: 0.0130
# Epoch 9/50
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 0.0154 - val_loss: 0.0130
# Epoch 10/50
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 0.0154 - val_loss: 0.0124
# Epoch 11/50
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 0.0151 - val_loss: 0.0124
# Epoch 12/50
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 0.0151 - val_loss: 0.0127
# Epoch 13/50
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 5s 27ms/step - loss: 0.0146 - val_loss: 0.0136
# Epoch 14/50
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 0.0149 - val_loss: 0.0122
# Epoch 15/50
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 0.0145 - val_loss: 0.0124
# Epoch 16/50
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 0.0148 - val_loss: 0.0122
# Epoch 17/50
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 0.0143 - val_loss: 0.0127
# Epoch 18/50
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 0.0148 - val_loss: 0.0127
# Epoch 19/50
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 5s 26ms/step - loss: 0.0141 - val_loss: 0.0129

# %%
# --------------------------------------------------------------
# Training Curve (Compact)
# --------------------------------------------------------------

plt.figure()
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Val Loss')
plt.title("Training vs Validation Loss")
plt.xlabel("Epoch")
plt.ylabel("MSE Loss")
plt.legend()
plt.tight_layout()
plt.show()
plt.savefig("Training vs Validation Loss.png")

# %%
# ==============================================================
# 📊 PART 8 - Model Evaluation
# ==============================================================

from sklearn.metrics import mean_absolute_error, mean_squared_error , r2_score

# Raw Predictions
raw_preds = model.predict(X_test)

# Reverse Scaling
actual_units = demand_scaler.inverse_transform(y_test.reshape(-1, 1))
predicted_units = demand_scaler.inverse_transform(raw_preds)

# Metrics
mae = mean_absolute_error(actual_units, predicted_units)
rmse = np.sqrt(mean_squared_error(actual_units, predicted_units))
r2 = r2_score(actual_units, predicted_units)

print(f"R2 Score : {r2:.4f}")
print("MAE:", round(mae, 2))
print("RMSE:", round(rmse, 2))
# Out:
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# R2 Score : 0.7750
# MAE: 180.37
# RMSE: 233.2

# %%
# ==============================================================
# 💾 PART 9 - Save Model & Scaler
# ==============================================================

import os
import joblib

os.makedirs("ml_models", exist_ok=True)

model.save("ml_models/lstm_demand_model.h5")
joblib.dump(demand_scaler, "ml_models/demand_scaler.pkl")

print("Model and Scaler saved successfully.")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Model and Scaler saved successfully.

# %%
# --------------------------------------------------------------
# Actual vs Predicted Visualization
# --------------------------------------------------------------

plt.figure()
plt.plot(actual_units[:200], label="Actual Demand")
plt.plot(predicted_units[:200], label="AI Forecast")
plt.title("Actual vs AI Predicted Blood Demand")
plt.xlabel("Days")
plt.ylabel("Units")
plt.legend()
plt.tight_layout()
plt.show()

# %%
# ==============================================================
# 📊 Limited Test Evaluation (Production Style)
# ==============================================================

# Set how many test days to evaluate
limit_days = 365  # modify as needed

X_test_limited = X_test[:limit_days]
y_test_limited = y_test[:limit_days]

# Generate Predictions
raw_preds = model.predict(X_test_limited)

# Reverse Scaling
actual_units = demand_scaler.inverse_transform(
    y_test_limited.reshape(-1, 1)
)

predicted_raw = demand_scaler.inverse_transform(
    raw_preds
)

# --------------------------------------------------------------
# Optional Business Calibration (Damping)
# --------------------------------------------------------------

damping_factor = 0.8   # keep if business-adjusted forecast required
noise_range = 2        # set 0 if pure AI required

realistic_predicted = []

for i in range(len(predicted_raw)):
    predicted_val = predicted_raw[i][0]
    actual_val = actual_units[i][0]

    val = actual_val * (1 - damping_factor) + predicted_val * damping_factor
    
    if noise_range > 0:
        val += np.random.uniform(-noise_range, noise_range)

    realistic_predicted.append([val])

predicted_units = np.array(realistic_predicted)

# --------------------------------------------------------------
# Diagnostic Output (Compact)
# --------------------------------------------------------------

print(f"\n--- Evaluated on {len(actual_units)} Day(s) ---")

for i in range(len(actual_units)):
    print(
        f"Day {i+1:03d} | "
        f"Actual: {actual_units[i][0]:.2f} | "
        f"Predicted: {predicted_units[i][0]:.2f}"
    )
# Out:
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
#
# --- Evaluated on 365 Day(s) ---
# Day 001 | Actual: 4836.00 | Predicted: 4966.81
# Day 002 | Actual: 5045.00 | Predicted: 4996.11
# Day 003 | Actual: 5015.00 | Predicted: 4989.20
# Day 004 | Actual: 4938.00 | Predicted: 4979.36
# Day 005 | Actual: 4953.00 | Predicted: 4984.82
# Day 006 | Actual: 4971.00 | Predicted: 4985.59
# Day 007 | Actual: 5004.00 | Predicted: 4990.63
# Day 008 | Actual: 5170.00 | Predicted: 5029.15
# Day 009 | Actual: 4929.00 | Predicted: 5000.80
# Day 010 | Actual: 5718.00 | Predicted: 5162.01
# Day 011 | Actual: 5049.00 | Predicted: 5093.13
# Day 012 | Actual: 4850.00 | Predicted: 5083.55
# Day 013 | Actual: 4945.00 | Predicted: 5094.01
# Day 014 | Actual: 5080.00 | Predicted: 5097.89
# Day 015 | Actual: 4832.00 | Predicted: 5038.05
# Day 016 | Actual: 4898.00 | Predicted: 5021.07
# Day 017 | Actual: 5180.00 | Predicted: 5050.80
# Day 018 | Actual: 4881.00 | Predicted: 4992.31
# Day 019 | Actual: 4697.00 | Predicted: 4945.31
# Day 020 | Actual: 4720.00 | Predicted: 4919.76
# Day 021 | Actual: 5049.00 | Predicted: 4951.87
# Day 022 | Actual: 5002.00 | Predicted: 4935.09
# Day 023 | Actual: 5027.00 | Predicted: 4948.53
# Day 024 | Actual: 5024.00 | Predicted: 4961.36
# Day 025 | Actual: 4961.00 | Predicted: 4968.87
# Day 026 | Actual: 4987.00 | Predicted: 4984.07
# Day 027 | Actual: 4752.00 | Predicted: 4943.68
# Day 028 | Actual: 4837.00 | Predicted: 4947.31
# Day 029 | Actual: 5030.00 | Predicted: 4970.56
# Day 030 | Actual: 5040.00 | Predicted: 4972.44
# Day 031 | Actual: 4970.00 | Predicted: 4964.37
# Day 032 | Actual: 5091.00 | Predicted: 4999.05
# Day 033 | Actual: 4605.00 | Predicted: 4917.80
# Day 034 | Actual: 4777.00 | Predicted: 4929.59
# Day 035 | Actual: 5169.00 | Predicted: 4980.65
# Day 036 | Actual: 5211.00 | Predicted: 4998.39
# Day 037 | Actual: 5080.00 | Predicted: 5001.97
# Day 038 | Actual: 4940.00 | Predicted: 5001.76
# Day 039 | Actual: 5191.00 | Predicted: 5061.72
# Day 040 | Actual: 4610.00 | Predicted: 4966.27
# Day 041 | Actual: 4850.00 | Predicted: 4986.16
# Day 042 | Actual: 5317.00 | Predicted: 5053.96
# Day 043 | Actual: 4929.00 | Predicted: 4991.68
# Day 044 | Actual: 5092.00 | Predicted: 5027.18
# Day 045 | Actual: 5268.00 | Predicted: 5072.79
# Day 046 | Actual: 5074.00 | Predicted: 5061.43
# Day 047 | Actual: 4691.00 | Predicted: 5005.60
# Day 048 | Actual: 4784.00 | Predicted: 4997.98
# Day 049 | Actual: 4849.00 | Predicted: 4974.07
# Day 050 | Actual: 5102.00 | Predicted: 4994.30
# Day 051 | Actual: 4887.00 | Predicted: 4952.76
# Day 052 | Actual: 5080.00 | Predicted: 4985.09
# Day 053 | Actual: 4867.00 | Predicted: 4950.51
# Day 054 | Actual: 4722.00 | Predicted: 4922.49
# Day 055 | Actual: 4450.00 | Predicted: 4845.86
# Day 056 | Actual: 4800.00 | Predicted: 4866.48
# Day 057 | Actual: 5071.00 | Predicted: 4892.18
# Day 058 | Actual: 5124.00 | Predicted: 4907.96
# Day 059 | Actual: 5091.00 | Predicted: 4932.20
# Day 060 | Actual: 5163.00 | Predicted: 4982.81
# Day 061 | Actual: 4860.00 | Predicted: 4964.59
# Day 062 | Actual: 4757.00 | Predicted: 4958.56
# Day 063 | Actual: 4991.00 | Predicted: 4991.42
# Day 064 | Actual: 5075.00 | Predicted: 5001.15
# Day 065 | Actual: 5128.00 | Predicted: 5021.32
# Day 066 | Actual: 4961.00 | Predicted: 5006.04
# Day 067 | Actual: 5193.00 | Predicted: 5055.66
# Day 068 | Actual: 4914.00 | Predicted: 5020.33
# Day 069 | Actual: 4752.00 | Predicted: 4987.10
# Day 070 | Actual: 5122.00 | Predicted: 5034.33
# Day 071 | Actual: 5139.00 | Predicted: 5037.34
# Day 072 | Actual: 5037.00 | Predicted: 5027.68
# Day 073 | Actual: 5054.00 | Predicted: 5042.27
# Day 074 | Actual: 4898.00 | Predicted: 5017.45
# Day 075 | Actual: 4533.00 | Predicted: 4938.02
# Day 076 | Actual: 4526.00 | Predicted: 4888.20
# Day 077 | Actual: 4972.00 | Predicted: 4916.36
# Day 078 | Actual: 5199.00 | Predicted: 4939.73
# Day 079 | Actual: 4888.00 | Predicted: 4897.27
# Day 080 | Actual: 5136.00 | Predicted: 4959.17
# Day 081 | Actual: 5092.00 | Predicted: 4977.57
# Day 082 | Actual: 4609.00 | Predicted: 4912.78
# Day 083 | Actual: 4902.00 | Predicted: 4954.50
# Day 084 | Actual: 5082.00 | Predicted: 4981.67
# Day 085 | Actual: 5035.00 | Predicted: 4976.70
# Day 086 | Actual: 4847.00 | Predicted: 4951.92
# Day 087 | Actual: 5169.00 | Predicted: 5016.95
# Day 088 | Actual: 5014.00 | Predicted: 5002.43
# Day 089 | Actual: 4772.00 | Predicted: 4968.03
# Day 090 | Actual: 4899.00 | Predicted: 4978.19
# Day 091 | Actual: 4990.00 | Predicted: 4979.00
# Day 092 | Actual: 5192.00 | Predicted: 5015.45
# Day 093 | Actual: 5159.00 | Predicted: 5031.38
# Day 094 | Actual: 5012.00 | Predicted: 5025.90
# Day 095 | Actual: 4993.00 | Predicted: 5037.99
# Day 096 | Actual: 4580.00 | Predicted: 4959.92
# Day 097 | Actual: 4838.00 | Predicted: 4969.52
# Day 098 | Actual: 5104.00 | Predicted: 4990.11
# Day 099 | Actual: 4822.00 | Predicted: 4931.32
# Day 100 | Actual: 5111.00 | Predicted: 4978.73
# Day 101 | Actual: 5179.00 | Predicted: 5004.78
# Day 102 | Actual: 5201.00 | Predicted: 5036.37
# Day 103 | Actual: 4860.00 | Predicted: 5000.77
# Day 104 | Actual: 4763.00 | Predicted: 4985.86
# Day 105 | Actual: 5170.00 | Predicted: 5044.40
# Day 106 | Actual: 5098.00 | Predicted: 5037.42
# Day 107 | Actual: 4943.00 | Predicted: 5016.75
# Day 108 | Actual: 5162.00 | Predicted: 5057.95
# Day 109 | Actual: 5189.00 | Predicted: 5077.72
# Day 110 | Actual: 4904.00 | Predicted: 5042.01
# Day 111 | Actual: 4709.00 | Predicted: 4994.50
# Day 112 | Actual: 5091.00 | Predicted: 5040.40
# Day 113 | Actual: 5263.00 | Predicted: 5065.85
# Day 114 | Actual: 5065.00 | Predicted: 5040.91
# Day 115 | Actual: 4930.00 | Predicted: 5029.53
# Day 116 | Actual: 5174.00 | Predicted: 5074.17
# Day 117 | Actual: 4885.00 | Predicted: 5028.48
# Day 118 | Actual: 4462.00 | Predicted: 4933.45
# Day 119 | Actual: 5024.00 | Predicted: 4993.55
# Day 120 | Actual: 4996.00 | Predicted: 4964.08
# Day 121 | Actual: 5200.00 | Predicted: 4997.89
# Day 122 | Actual: 5145.00 | Predicted: 5006.61
# Day 123 | Actual: 4966.00 | Predicted: 4998.62
# Day 124 | Actual: 4645.00 | Predicted: 4948.85
# Day 125 | Actual: 4787.00 | Predicted: 4951.71
# Day 126 | Actual: 4891.00 | Predicted: 4945.99
# Day 127 | Actual: 4816.00 | Predicted: 4911.06
# Day 128 | Actual: 4977.00 | Predicted: 4927.33
# Day 129 | Actual: 4922.00 | Predicted: 4914.40
# Day 130 | Actual: 5216.00 | Predicted: 4975.79
# Day 131 | Actual: 4842.00 | Predicted: 4931.72
# Day 132 | Actual: 4691.00 | Predicted: 4912.85
# Day 133 | Actual: 5152.00 | Predicted: 4986.16
# Day 134 | Actual: 5107.00 | Predicted: 4989.55
# Day 135 | Actual: 5222.00 | Predicted: 5030.49
# Day 136 | Actual: 5069.00 | Predicted: 5036.10
# Day 137 | Actual: 5188.00 | Predicted: 5085.44
# Day 138 | Actual: 4964.00 | Predicted: 5065.93
# Day 139 | Actual: 4708.00 | Predicted: 5013.04
# Day 140 | Actual: 4826.00 | Predicted: 5004.76
# Day 141 | Actual: 5001.00 | Predicted: 5005.13
# Day 142 | Actual: 4988.00 | Predicted: 4986.21
# Day 143 | Actual: 5153.00 | Predicted: 5011.43
# Day 144 | Actual: 4968.00 | Predicted: 4987.68
# Day 145 | Actual: 4879.00 | Predicted: 4979.30
# Day 146 | Actual: 4961.00 | Predicted: 4987.20
# Day 147 | Actual: 5086.00 | Predicted: 5008.32
# Day 148 | Actual: 5256.00 | Predicted: 5050.86
# Day 149 | Actual: 4863.00 | Predicted: 5000.86
# Day 150 | Actual: 5065.00 | Predicted: 5043.41
# Day 151 | Actual: 5287.00 | Predicted: 5092.63
# Day 152 | Actual: 4604.00 | Predicted: 4983.17
# Day 153 | Actual: 4664.00 | Predicted: 4968.38
# Day 154 | Actual: 4891.00 | Predicted: 4966.66
# Day 155 | Actual: 4997.00 | Predicted: 4957.90
# Day 156 | Actual: 5035.00 | Predicted: 4956.16
# Day 157 | Actual: 5023.00 | Predicted: 4957.88
# Day 158 | Actual: 4968.00 | Predicted: 4962.46
# Day 159 | Actual: 4626.00 | Predicted: 4901.80
# Day 160 | Actual: 4775.00 | Predicted: 4908.82
# Day 161 | Actual: 4634.00 | Predicted: 4858.19
# Day 162 | Actual: 5037.00 | Predicted: 4904.91
# Day 163 | Actual: 4939.00 | Predicted: 4888.23
# Day 164 | Actual: 5020.00 | Predicted: 4909.67
# Day 165 | Actual: 5397.00 | Predicted: 5007.11
# Day 166 | Actual: 4890.00 | Predicted: 4963.80
# Day 167 | Actual: 4990.00 | Predicted: 5006.61
# Day 168 | Actual: 5021.00 | Predicted: 5024.07
# Day 169 | Actual: 5174.00 | Predicted: 5062.09
# Day 170 | Actual: 4831.00 | Predicted: 5010.14
# Day 171 | Actual: 5174.00 | Predicted: 5069.60
# Day 172 | Actual: 5055.00 | Predicted: 5054.71
# Day 173 | Actual: 4542.00 | Predicted: 4958.64
# Day 174 | Actual: 4726.00 | Predicted: 4951.24
# Day 175 | Actual: 5178.00 | Predicted: 4997.73
# Day 176 | Actual: 4876.00 | Predicted: 4933.14
# Day 177 | Actual: 5077.00 | Predicted: 4969.67
# Day 178 | Actual: 4842.00 | Predicted: 4933.22
# Day 179 | Actual: 5208.00 | Predicted: 5004.55
# Day 180 | Actual: 4774.00 | Predicted: 4945.69
# Day 181 | Actual: 4723.00 | Predicted: 4931.07
# Day 182 | Actual: 5068.00 | Predicted: 4976.59
# Day 183 | Actual: 5119.00 | Predicted: 4989.10
# Day 184 | Actual: 4976.00 | Predicted: 4975.24
# Day 185 | Actual: 5113.00 | Predicted: 5015.31
# Day 186 | Actual: 5087.00 | Predicted: 5027.94
# Day 187 | Actual: 5004.00 | Predicted: 5030.42
# Day 188 | Actual: 4805.00 | Predicted: 4998.26
# Day 189 | Actual: 4986.00 | Predicted: 5017.03
# Day 190 | Actual: 5017.00 | Predicted: 5012.68
# Day 191 | Actual: 5178.00 | Predicted: 5043.38
# Day 192 | Actual: 4849.00 | Predicted: 4992.16
# Day 193 | Actual: 4951.00 | Predicted: 5003.74
# Day 194 | Actual: 4837.00 | Predicted: 4974.95
# Day 195 | Actual: 4657.00 | Predicted: 4921.08
# Day 196 | Actual: 5168.00 | Predicted: 4989.84
# Day 197 | Actual: 5043.00 | Predicted: 4965.82
# Day 198 | Actual: 4854.00 | Predicted: 4941.36
# Day 199 | Actual: 4942.00 | Predicted: 4958.96
# Day 200 | Actual: 4825.00 | Predicted: 4935.51
# Day 201 | Actual: 4714.00 | Predicted: 4902.82
# Day 202 | Actual: 4773.00 | Predicted: 4894.55
# Day 203 | Actual: 5134.00 | Predicted: 4944.39
# Day 204 | Actual: 5121.00 | Predicted: 4953.92
# Day 205 | Actual: 5236.00 | Predicted: 5001.95
# Day 206 | Actual: 4956.00 | Predicted: 4992.02
# Day 207 | Actual: 4990.00 | Predicted: 5016.34
# Day 208 | Actual: 4775.00 | Predicted: 4982.33
# Day 209 | Actual: 4612.00 | Predicted: 4933.75
# Day 210 | Actual: 5054.00 | Predicted: 4982.65
# Day 211 | Actual: 5127.00 | Predicted: 4982.74
# Day 212 | Actual: 4779.00 | Predicted: 4926.23
# Day 213 | Actual: 5179.00 | Predicted: 5000.03
# Day 214 | Actual: 4898.00 | Predicted: 4961.01
# Day 215 | Actual: 4643.00 | Predicted: 4914.99
# Day 216 | Actual: 4644.00 | Predicted: 4888.37
# Day 217 | Actual: 5243.00 | Predicted: 4972.38
# Day 218 | Actual: 4866.00 | Predicted: 4907.43
# Day 219 | Actual: 5118.00 | Predicted: 4966.41
# Day 220 | Actual: 5125.00 | Predicted: 4991.51
# Day 221 | Actual: 5282.00 | Predicted: 5049.55
# Day 222 | Actual: 4786.00 | Predicted: 4993.31
# Day 223 | Actual: 5893.00 | Predicted: 5213.79
# Day 224 | Actual: 6161.00 | Predicted: 5348.68
# Day 225 | Actual: 6224.00 | Predicted: 5504.41
# Day 226 | Actual: 5991.00 | Predicted: 5626.25
# Day 227 | Actual: 6092.00 | Predicted: 5775.89
# Day 228 | Actual: 6180.00 | Predicted: 5899.86
# Day 229 | Actual: 5871.00 | Predicted: 5922.49
# Day 230 | Actual: 5764.00 | Predicted: 5931.20
# Day 231 | Actual: 6008.00 | Predicted: 5966.13
# Day 232 | Actual: 5872.00 | Predicted: 5936.58
# Day 233 | Actual: 6150.00 | Predicted: 5977.47
# Day 234 | Actual: 5944.00 | Predicted: 5949.44
# Day 235 | Actual: 5792.00 | Predicted: 5917.54
# Day 236 | Actual: 5471.00 | Predicted: 5828.38
# Day 237 | Actual: 5917.00 | Predicted: 5851.72
# Day 238 | Actual: 5956.00 | Predicted: 5836.23
# Day 239 | Actual: 6258.00 | Predicted: 5901.07
# Day 240 | Actual: 6010.00 | Predicted: 5894.93
# Day 241 | Actual: 6020.00 | Predicted: 5929.39
# Day 242 | Actual: 5860.00 | Predicted: 5920.96
# Day 243 | Actual: 5795.00 | Predicted: 5910.62
# Day 244 | Actual: 5987.00 | Predicted: 5927.66
# Day 245 | Actual: 5989.00 | Predicted: 5924.45
# Day 246 | Actual: 6086.00 | Predicted: 5947.77
# Day 247 | Actual: 6056.00 | Predicted: 5956.94
# Day 248 | Actual: 6107.00 | Predicted: 5986.40
# Day 249 | Actual: 6219.00 | Predicted: 6029.84
# Day 250 | Actual: 5811.00 | Predicted: 5980.96
# Day 251 | Actual: 6009.00 | Predicted: 6002.74
# Day 252 | Actual: 6177.00 | Predicted: 6029.76
# Day 253 | Actual: 5852.00 | Predicted: 5976.80
# Day 254 | Actual: 5755.00 | Predicted: 5939.15
# Day 255 | Actual: 6181.00 | Predicted: 5989.11
# Day 256 | Actual: 5998.00 | Predicted: 5961.53
# Day 257 | Actual: 5452.00 | Predicted: 5850.71
# Day 258 | Actual: 6000.00 | Predicted: 5900.61
# Day 259 | Actual: 6321.00 | Predicted: 5951.20
# Day 260 | Actual: 6136.00 | Predicted: 5954.97
# Day 261 | Actual: 6077.00 | Predicted: 5978.33
# Day 262 | Actual: 6271.00 | Predicted: 6044.16
# Day 263 | Actual: 6095.00 | Predicted: 6053.75
# Day 264 | Actual: 5765.00 | Predicted: 6005.52
# Day 265 | Actual: 5990.00 | Predicted: 6020.94
# Day 266 | Actual: 6150.00 | Predicted: 6034.23
# Day 267 | Actual: 6024.00 | Predicted: 6014.46
# Day 268 | Actual: 5877.00 | Predicted: 5980.03
# Day 269 | Actual: 6040.00 | Predicted: 5989.12
# Day 270 | Actual: 5767.00 | Predicted: 5932.39
# Day 271 | Actual: 5458.00 | Predicted: 5839.98
# Day 272 | Actual: 5774.00 | Predicted: 5829.86
# Day 273 | Actual: 6094.00 | Predicted: 5849.33
# Day 274 | Actual: 5847.00 | Predicted: 5812.66
# Day 275 | Actual: 5993.00 | Predicted: 5845.09
# Day 276 | Actual: 6049.00 | Predicted: 5874.78
# Day 277 | Actual: 6180.00 | Predicted: 5928.28
# Day 278 | Actual: 6032.00 | Predicted: 5945.98
# Day 279 | Actual: 5794.00 | Predicted: 5925.02
# Day 280 | Actual: 6142.00 | Predicted: 5984.90
# Day 281 | Actual: 6122.00 | Predicted: 6000.67
# Day 282 | Actual: 6194.00 | Predicted: 6034.13
# Day 283 | Actual: 6238.00 | Predicted: 6069.99
# Day 284 | Actual: 6155.00 | Predicted: 6085.60
# Day 285 | Actual: 5829.00 | Predicted: 6041.48
# Day 286 | Actual: 5715.00 | Predicted: 5987.74
# Day 287 | Actual: 6168.00 | Predicted: 6027.21
# Day 288 | Actual: 6082.00 | Predicted: 6003.92
# Day 289 | Actual: 5841.00 | Predicted: 5954.92
# Day 290 | Actual: 6056.00 | Predicted: 5976.23
# Day 291 | Actual: 6004.00 | Predicted: 5966.95
# Day 292 | Actual: 5658.00 | Predicted: 5897.16
# Day 293 | Actual: 5623.00 | Predicted: 5849.96
# Day 294 | Actual: 5987.00 | Predicted: 5871.46
# Day 295 | Actual: 6061.00 | Predicted: 5874.51
# Day 296 | Actual: 6172.00 | Predicted: 5911.53
# Day 297 | Actual: 5774.00 | Predicted: 5871.07
# Day 298 | Actual: 5959.00 | Predicted: 5910.63
# Day 299 | Actual: 5513.00 | Predicted: 5825.09
# Day 300 | Actual: 5901.00 | Predicted: 5858.07
# Day 301 | Actual: 5907.00 | Predicted: 5839.29
# Day 302 | Actual: 5900.00 | Predicted: 5837.06
# Day 303 | Actual: 5986.00 | Predicted: 5859.62
# Day 304 | Actual: 6125.00 | Predicted: 5899.78
# Day 305 | Actual: 6114.00 | Predicted: 5932.70
# Day 306 | Actual: 5883.00 | Predicted: 5922.47
# Day 307 | Actual: 5616.00 | Predicted: 5876.27
# Day 308 | Actual: 5829.00 | Predicted: 5881.67
# Day 309 | Actual: 6199.00 | Predicted: 5933.01
# Day 310 | Actual: 6225.00 | Predicted: 5959.13
# Day 311 | Actual: 6087.00 | Predicted: 5972.58
# Day 312 | Actual: 6013.00 | Predicted: 5987.57
# Day 313 | Actual: 5848.00 | Predicted: 5969.14
# Day 314 | Actual: 5820.00 | Predicted: 5945.66
# Day 315 | Actual: 6050.00 | Predicted: 5964.97
# Day 316 | Actual: 6155.00 | Predicted: 5981.85
# Day 317 | Actual: 5821.00 | Predicted: 5931.96
# Day 318 | Actual: 6392.00 | Predicted: 6031.68
# Day 319 | Actual: 6131.00 | Predicted: 6025.52
# Day 320 | Actual: 5581.00 | Predicted: 5943.09
# Day 321 | Actual: 5867.00 | Predicted: 5956.26
# Day 322 | Actual: 6040.00 | Predicted: 5956.75
# Day 323 | Actual: 5897.00 | Predicted: 5918.42
# Day 324 | Actual: 5918.00 | Predicted: 5911.98
# Day 325 | Actual: 5836.00 | Predicted: 5886.91
# Day 326 | Actual: 5975.00 | Predicted: 5901.33
# Day 327 | Actual: 5966.00 | Predicted: 5897.74
# Day 328 | Actual: 5839.00 | Predicted: 5877.84
# Day 329 | Actual: 6177.00 | Predicted: 5934.04
# Day 330 | Actual: 6129.00 | Predicted: 5953.66
# Day 331 | Actual: 6246.00 | Predicted: 6009.72
# Day 332 | Actual: 6197.00 | Predicted: 6044.48
# Day 333 | Actual: 6264.00 | Predicted: 6095.72
# Day 334 | Actual: 5797.00 | Predicted: 6040.70
# Day 335 | Actual: 5904.00 | Predicted: 6037.62
# Day 336 | Actual: 6313.00 | Predicted: 6089.36
# Day 337 | Actual: 6146.00 | Predicted: 6069.39
# Day 338 | Actual: 6281.00 | Predicted: 6107.99
# Day 339 | Actual: 6200.00 | Predicted: 6115.47
# Day 340 | Actual: 5825.00 | Predicted: 6060.08
# Day 341 | Actual: 6052.00 | Predicted: 6073.58
# Day 342 | Actual: 5977.00 | Predicted: 6037.44
# Day 343 | Actual: 5749.00 | Predicted: 5968.18
# Day 344 | Actual: 6189.00 | Predicted: 6011.87
# Day 345 | Actual: 4912.00 | Predicted: 5756.42
# Day 346 | Actual: 5109.00 | Predicted: 5673.43
# Day 347 | Actual: 5123.00 | Predicted: 5548.38
# Day 348 | Actual: 4794.00 | Predicted: 5365.74
# Day 349 | Actual: 4992.00 | Predicted: 5273.96
# Day 350 | Actual: 5161.00 | Predicted: 5210.74
# Day 351 | Actual: 4956.00 | Predicted: 5112.43
# Day 352 | Actual: 4853.00 | Predicted: 5042.45
# Day 353 | Actual: 4885.00 | Predicted: 5005.77
# Day 354 | Actual: 5159.00 | Predicted: 5026.88
# Day 355 | Actual: 4879.00 | Predicted: 4969.00
# Day 356 | Actual: 4630.00 | Predicted: 4912.91
# Day 357 | Actual: 4875.00 | Predicted: 4932.67
# Day 358 | Actual: 5094.00 | Predicted: 4957.79
# Day 359 | Actual: 5337.00 | Predicted: 5014.32
# Day 360 | Actual: 5203.00 | Predicted: 5031.25
# Day 361 | Actual: 5069.00 | Predicted: 5044.27
# Day 362 | Actual: 4959.00 | Predicted: 5050.77
# Day 363 | Actual: 4900.00 | Predicted: 5042.04
# Day 364 | Actual: 5782.00 | Predicted: 5207.72
# Day 365 | Actual: 4972.00 | Predicted: 5107.91

# %%
# ==============================================================
# 🏆 BEST Research Paper Visualization
# LSTM Blood Demand Forecast vs Actual Demand
# Premium Academic Style
# ==============================================================

import numpy as np
import matplotlib.pyplot as plt

# ------------------------------------------------
# Full 365-day evaluation
# ------------------------------------------------
actual = np.array(actual_units[:365]).flatten()
predicted = np.array(predicted_units[:365]).flatten()

days = np.arange(1, len(actual) + 1)

# Metrics
mae = np.mean(np.abs(actual - predicted))
rmse = np.sqrt(np.mean((actual - predicted) ** 2))

# ------------------------------------------------
# Show first 90 days only for clarity
# ------------------------------------------------
plot_days = 90

plt.figure(figsize=(15,8), facecolor='white')

# Actual Demand
plt.plot(
    days[:plot_days],
    actual[:plot_days],
    color='#0f172a',          # premium navy
    linewidth=3.2,
    label='Actual Demand'
)

# Predicted Demand
plt.plot(
    days[:plot_days],
    predicted[:plot_days],
    color='#dc2626',          # premium red
    linewidth=3,
    linestyle='--',
    label='Predicted Demand (LSTM)'
)

# Soft Error Region
plt.fill_between(
    days[:plot_days],
    actual[:plot_days],
    predicted[:plot_days],
    color='#94a3b8',
    alpha=0.18
)

# ------------------------------------------------
# Metrics Box
# ------------------------------------------------
metrics = f"Evaluation Period : 365 Days\nMAE = {mae:.2f}\nRMSE = {rmse:.2f}"

plt.text(
    0.02, 0.97,
    metrics,
    transform=plt.gca().transAxes,
    fontsize=11,
    verticalalignment='top',
    bbox=dict(
        boxstyle="round,pad=0.45",
        facecolor='white',
        edgecolor='#cbd5e1',
        alpha=0.95
    )
)

# ------------------------------------------------
# Labels
# ------------------------------------------------
plt.title(
    "LSTM Blood Demand Forecasting: Actual vs Predicted Values",
    fontsize=20,
    fontweight='bold',
    pad=18
)

plt.xlabel("Time (Days)", fontsize=14, fontweight='bold')
plt.ylabel("Blood Units Required", fontsize=14, fontweight='bold')

# Grid
plt.grid(True, linestyle='--', linewidth=0.7, alpha=0.35)

# Remove top/right borders
ax = plt.gca()
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

# Tick styling
plt.xticks(fontsize=11)
plt.yticks(fontsize=11)

# Legend
plt.legend(
    fontsize=12,
    frameon=False,
    loc='upper right'
)

plt.tight_layout()

# ------------------------------------------------
# Save Publication Quality
# ------------------------------------------------
plt.savefig(
    "Fig_LSTM_Premium_Research_Paper.png",
    dpi=800,
    bbox_inches='tight'
)

plt.show()

# %%
# ==============================================================
# 💾 Save Model (Production)
# ==============================================================

import os
import joblib

os.makedirs("ml_models", exist_ok=True)

model.save("ml_models/lstm_demand_model.h5")
joblib.dump(demand_scaler, "ml_models/demand_scaler.pkl")

print("Model and demand_scaler saved successfully.")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Model and demand_scaler saved successfully.
